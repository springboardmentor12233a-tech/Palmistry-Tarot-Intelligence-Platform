# %%
import os

os.environ["PALMISTRY_CODE_DIR"] = r"C:\Users\souri\Downloads\Palmistry & Tarot Intelligence\palmistry-main\palmistry-main\code"

# %%
import os
import cv2

image_path = r"C:\Users\souri\Downloads\Palmistry & Tarot Intelligence\palmistry-main\palmistry-main\code\input\Hand_0001657.jpg"

print("Exists:", os.path.exists(image_path))

img = cv2.imread(image_path)
print("Image loaded:", img is not None)

if img is not None:
    print("Shape:", img.shape)
# Out:
# Exists: True
# Image loaded: True
# Shape: (1200, 1600, 3)

# %%
ok, path, err = run_palm_analysis(
    r"C:\Users\souri\Downloads\Palmistry & Tarot Intelligence\palmistry-main\palmistry-main\code\input\Hand_0001657.jpg",
    repo_code_dir=repo_dir
)

print("Success:", ok)
print("Result:", path)
print("Error:", err)
# Out:
# Success: True
# Result: C:\Users\souri\Downloads\Palmistry & Tarot Intelligence\palmistry-main\palmistry-main\code\results\result.jpg
# Error: None

# %%
from PIL import Image
import matplotlib.pyplot as plt
result_path=r"C:\Users\souri\Downloads\Palmistry & Tarot Intelligence\palmistry-main\palmistry-main\code\results\result.jpg"
img = Image.open(result_path)

plt.figure(figsize=(8,8))
plt.imshow(img)
plt.axis("off")
plt.show()
