# %%
import pandas as pd
import json

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-63bfc500-652e-41e4-9bca-9bcda4603d63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63bfc500-652e-41e4-9bca-9bcda4603d63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c498cd99-a360-492d-a455-449d30cb0e57" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c498cd99-a360-492d-a455-449d30cb0e57">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-274c9f52-ff99-4558-bc68-043d0cbad19f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-274c9f52-ff99-4558-bc68-043d0cbad19f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
palm_df = pd.read_csv("palm_engineered_features.csv")

with open("tarot-images.json","r") as file:
    tarot = json.load(file)

with open("final_reading.txt","r") as file:
    reading = file.read()

print("Files Loaded Successfully")
# Out:
# Files Loaded Successfully

# %%
sample = palm_df.iloc[0]

sample
# Out:
# imageName        Hand_0000038.jpg
# aspectOfHand          palmar left
# x0                       0.689648
# y0                      -0.112166
# z0                       0.000001
#                        ...
# index_length             0.385593
# middle_length            0.441284
# ring_length              0.415338
# little_length             0.33909
# palm_ratio               1.712118
# Name: 0, Length: 73, dtype: object

# %%
report = f"""
==========================================
          PALMISTRY & TAROT REPORT
==========================================

Palm Analysis

Palm Width      : {sample['palm_width']:.3f}
Palm Height     : {sample['palm_height']:.3f}
Palm Ratio      : {sample['palm_ratio']:.3f}

Thumb Length    : {sample['thumb_length']:.3f}
Index Length    : {sample['index_length']:.3f}
Middle Length   : {sample['middle_length']:.3f}
Ring Length     : {sample['ring_length']:.3f}
Little Length   : {sample['little_length']:.3f}


------------------------------------------
Generated Reading
------------------------------------------

{reading}

==========================================
End of Report
==========================================
"""

# %%
print(report)
# Out:
# ...
#           PALMISTRY & TAROT REPORT
# ...
#
# Palm Analysis
#
# Palm Width      : 0.240
# Palm Height     : 0.412
# Palm Ratio      : 1.712
#
# Thumb Length    : 0.143
# Index Length    : 0.386
# Middle Length   : 0.441
# Ring Length     : 0.415
# Little Length   : 0.339
#
#
# ------------------------------------------
# Generated Reading
# ------------------------------------------
#
#
# PALM + TAROT READING
#
# Palm Analysis
#
# - You are practical and goal-oriented.
# - You are patient and thoughtful.
#
# Tarot Card
#
# The Chariot
#
# Keywords
#
# advancement, victory, triumph, success
#
# Fortune
#
# Victory is a certainty
#
# Overall Reading
#
# Your palm characteristics and today's tarot card suggest that you should focus on your goals, remain patient during challenges, and make thoughtful decisions while embracing new opportunities.
#
#
# ...
# End of Report
# ...

# %%
with open("Palmistry_Report.txt","w") as file:
    file.write(report)

print("Report Generated Successfully")
# Out:
# Report Generated Successfully

# %%
from google.colab import files

files.download("Palmistry_Report.txt")
